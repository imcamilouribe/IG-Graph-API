# %%
import pandas as pd
from classes.nombre import Nombre

# %%
data = {
    "business_discovery": {
    "followers_count": 528,
    "media_count": 29,
    "profile_picture_url": "https://scontent-bog1-1.xx.fbcdn.net/v/t51.2885-15/262134859_1086944065468667_1318638229565490392_n.jpg?_nc_cat=105&ccb=1-5&_nc_sid=86c713&_nc_eui2=AeE-xg2wFpDhrYB8lHTqnpigAXXQFvCtVrEBddAW8K1WsT4rlMwIf37zBdZazot7dMZMdpJL8D-KLSivTyCGKk7L&_nc_ohc=7DmiEr5O6wAAX_Z-Qsz&_nc_ht=scontent-bog1-1.xx&edm=AL-3X8kEAAAA&oh=00_AT9SSoBk7IssnJEV0wYgogLJcD8E9gpmJgRLBTHC7jvVoQ&oe=620AFE85",
    "username": "imcamilouribe",
    "name": "Camilo Uribe Navas",
    "biography": "Ing en Sistemas",
      "media": {
        "data": [
          {
            "comments_count": 1,
            "like_count": 28,
            "media_url": "https://video-bog1-1.cdninstagram.com/v/t50.16885-16/273393114_2826100654355766_1154221578046845050_n.mp4?_nc_cat=108&vs=659607598723470_1217071111&_nc_vs=HBksFQAYJEdOcWxTeEEyTlpyVlVnb0tBSHF3a3U5b25nUVFidlZCQUFBRhUAAsgBABUAGCRHR09kUWhDV3dDOERkT0FBQUJqR2s3ejFvWm9DYnZWQkFBQUYVAgLIAQAoABgAGwGIB3VzZV9vaWwBMRUAACa0yObt1r3RPxUCKAJDMywXQCDEGJN0vGoYEmRhc2hfYmFzZWxpbmVfMV92MREAdewHAA%3D%3D&ccb=1-5&_nc_sid=59939d&efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5pZ3R2In0%3D&_nc_eui2=AeEJQafROOaGoLhlPnyyC-vVjUA8WZToUUWNQDxZlOhRRUB4lTuboudkXVfTfBlvixQbAfaV7tIl4vuvao6LaXHF&_nc_ohc=rdpKzTr38YQAX-XGbKp&_nc_oc=AQmSZsmeJRlOs9DqCe36jvIMjAdcoQEax2aOfKGl9QpCHExY-kRC3yUf7rH_XFrFGDQ&_nc_ht=video-bog1-1.cdninstagram.com&edm=AL-3X8kEAAAA&oh=00_AT_1k3Du9pEjrebkAxi433tZzv2BiIAfg8GIkAmArR-DEw&oe=6205F53B&_nc_rid=0e803f3410",
            "caption": "Un tbt que me tenía guardado de hace tiempo, fui tan feliz de llegar a mi casa y contarles a todos que pegue mi primer 360, mi cara lo dice todo",
            "timestamp": "2022-02-04T02:21:44+0000",
            "id": "17912576750199050"
          },
          {
            "comments_count": 3,
            "like_count": 26,
            "media_url": "https://scontent-bog1-1.cdninstagram.com/v/t51.29350-15/272432580_264768899097661_5014297523432767169_n.jpg?_nc_cat=106&ccb=1-5&_nc_sid=8ae9d6&_nc_eui2=AeFmevO6eVG8DLenhYYwx0HjUGMkrvEgwspQYySu8SDCylcXtCDsHDdfaOF8fbjl2Jy9hJ4WWrR05Gzk00wJnzjK&_nc_ohc=BKnIzeRnh_EAX_pJrPm&_nc_ht=scontent-bog1-1.cdninstagram.com&edm=AL-3X8kEAAAA&oh=00_AT9g7j1ZWZdiESPySQaT7pG620aoC-W4RUcaJZk5hESIgQ&oe=6209E767",
            "caption": "Be wild, but stay soft. (Like the waves) 🌴🌊",
            "timestamp": "2022-01-25T00:20:58+0000",
            "id": "17920720367155928"
          },
          {
            "comments_count": 4,
            "like_count": 38,
            "media_url": "https://scontent-bog1-1.cdninstagram.com/v/t51.29350-15/269835571_284586140183787_5805117014767872579_n.jpg?_nc_cat=108&ccb=1-5&_nc_sid=8ae9d6&_nc_eui2=A
ccb=1-5&_nc_sid=8ae9d6&_nc_eui2=AeHCyLqXaDGv5dzpDh60hLqMwXQscRgFx-_BdCxxGAXH7xsD0IOreD68LIYnlou-jSm3LD-npfT3xlMlvCYURVrH&_nc_ohc=to-0HUWQHMIAX80yoPm&_nc_ht=scontent-bog1-1.cdninstagram.com&edm=AL-3X8kEAAAA&oh=00_AT_Vn1LaxZn-3IZLdTKTbdeh394DFJQxFjBMew03bAKBZg&oe=620A0AF2",
            "caption": "Si, esas son las 3 líneas matemáticas que separan mi vida como un hombre y mi vida como un fantasma sin sentimientos.",
            "timestamp": "2018-10-13T18:18:24+0000",
            "id": "17960350039183424"
          },
          {
            "comments_count": 0,
            "like_count": 26,
            "media_url": "https://scontent-bog1-1.cdninstagram.com/v/t51.2885-15/42480833_1981845005241077_423836181838618733_n.jpg?_nc_cat=108&ccb=1-5&_nc_sid=8ae9d6&_nc_eui2=AeEy9VGycDQW3FtGUen6w_gEEWqWuHQxRIURapa4dDFEhdJFB3oIhqv2RSUSDP-UzuKOwaYVOL6_rkER2WbBPyMx&_nc_ohc=kBM9YtMlYDIAX-AvhrG&_nc_ht=scontent-bog1-1.cdninstagram.com&edm=AL-3X8kEAAAA&oh=00_AT-KiVwZXRK75wtVA0Rbi_w5aQybierhISWOBtXKJkMplA&oe=6209D1F8",
            "caption": "Its just the way I be Its just the way I see things",
            "timestamp": "2018-10-05T13:59:03+0000",
            "id": "17985525586009946"
          },
          {
            "comments_count": 0,
            "like_count": 35,
            "media_url": "https://scontent-bog1-1.cdninstagram.com/v/t51.2885-15/39325984_262044317764248_7315587996793700352_n.jpg?_nc_cat=107&ccb=1-5&_nc_sid=8ae9d6&_nc_eui2=AeFf6hBBp1siswHtz4XwSGc1V4v9CYwQl5JXi_0JjBCXkhAocH7ckXQKqGX_sJsJwvCPhgAMCqpUw_EM0DjSOwKo&_nc_ohc=ctVqlFxY9H8AX9Q7zXD&_nc_ht=scontent-bog1-1.cdninstagram.com&edm=AL-3X8kEAAAA&oh=00_AT_Om5vpbtYo3b6_YftQL1wTJr_LGDa9CHMGCWERA7TK-g&oe=620AB02F",
            "caption": "I'm a mothafuckin' schemer boy, I'm a dreamer boy  I love a girl that don't even fuckin' need a boy.",
            "timestamp": "2018-08-25T16:38:50+0000",
            "id": "17843180188292069"
          },
          {
            "comments_count": 0,
            "like_count": 26,
            "media_url": "https://scontent-bog1-1.cdninstagram.com/v/t51.2885-15/39298431_538770796556449_4512817752469143552_n.jpg?_nc_cat=102&ccb=1-5&_nc_sid=8ae9d6&_nc_eui2=AeE_jzhXyJU_xrOVje3AulyH8F5ZS69ym5zwXllLr3KbnLW0oFXiY5liXp8-12doT13YVXT-h3bts74y94QB1EW2&_nc_ohc=FrrbbPptnVIAX9FKbxU&_nc_ht=scontent-bog1-1.cdninstagram.com&edm=AL-3X8kEAAAA&oh=00_AT-oyr3u0TtOhbnyOur_19AlwOnZmrAHX-dMKFuskSoL0Q&oe=620A8BC4",
            "caption": "The greatest art of life is sensation, to feel that we exist, even in pain.",
            "timestamp": "2018-08-21T16:43:23+0000",
            "id": "17948058616138841"
          },
          {
            "comments_count": 0,
            "like_count": 32,
            "media_url": "https://scontent-bog1-1.cdninstagram.com/v/t51.2885-15/38751220_457613741374327_4496579778203090944_n.jpg?_nc_cat=108&ccb=1-5&_nc_sid=8ae9d6&_nc_eui2=AeGioYSXjbmT2WkfSDmH3IMAFxLkr0t6qCIXEuSvS3qoIuvKgwHdKaAlm7m-0wlkSO24x5M03vRDx6NK8Ulnz9r0&_nc_ohc=vDIiGTcWc3UAX93hySR&_nc_ht=scontent-bog1-1.cdninstagram.com&edm=AL-3X8kEAAAA&oh=00_AT-l0Tt2R8v4rSSvaVe9w43Zfi6544aZB4jvAwTe_xB8uw&oe=620A8F38",
            "caption": "I’m having this inner conflict all the time: “I have been through so much. I can take any kind of pain”  vs. “I have been through so much. I cannot take any more pain.”",
            "timestamp": "2018-08-12T18:09:44+0000",
            "id": "17969491471018379"
          }
        ],
        "paging": {
          "cursors": {
            "after": "QVFIUmNHdzZAZAZAF9BUDJkV210LUZATa1lrWGliQnZAmSTUxMlkxZAFZAkNk9KbWZATcktiTXVCU2I2d3ZAMbWxXaG5HT1VScWFRaGN4WUg2c0dnNW1QR2ZAIWGZAWQzJB"
          }
        }
      },
      "id": "17841401086937190"
    },
  "id": "17841401086937190"
}

# %%
import pandas as pd

#fecha_ini = str(input("Año inicial en formato")) #2019-01-01
#fecha_fin = str(input("Año final en formato")) #2020-12-31

array = []
for x in range(len(data["business_discovery"]["media"]["data"])):
    array.append(data["business_discovery"]["media"]["data"][x])

df = pd.DataFrame(array, columns=["comments_count","like_count","media_url","caption","timestamp","id"])
filtered_df = df.loc[df["timestamp"].between('2020-01-01', '2020-12-31')]

filtered_df["timestamp"] = filtered_df["timestamp"].str[0:10]
filtered_df
#filtered_df.to_excel('data.xlsx')

# %%
import pandas as pd

data2 = {
  "business_discovery": {
    "followers_count": 528,
    "media_count": 29,
    "profile_picture_url": "https://scontent-bog1-1.xx.fbcdn.net/v/t51.2885-15/262134859_1086944065468667_1318638229565490392_n.jpg?_nc_cat=105&ccb=1-5&_nc_sid=86c713&_nc_eui2=AeE-xg2wFpDhrYB8lHTqnpigAXXQFvCtVrEBddAW8K1WsT4rlMwIf37zBdZazot7dMZMdpJL8D-KLSivTyCGKk7L&_nc_ohc=7DmiEr5O6wAAX_Z-Qsz&_nc_ht=scontent-bog1-1.xx&edm=AL-3X8kEAAAA&oh=00_AT9SSoBk7IssnJEV0wYgogLJcD8E9gpmJgRLBTHC7jvVoQ&oe=620AFE85",
    "username": "imcamilouribe",
    "name": "Camilo Uribe Navas",
    "biography": "🄱🄼🅇 🅁🄸🄳🄴🅁 Ing en Sistemas | 22 years old | Cartagena - Colombia | 🏝☀️🅨🅞🅤🅖🅞🅞🅓?",
    "id": "17841401086937190"
  },
  "id": "17841401086937190"
}

array = []
array.append(data2["business_discovery"])

df = pd.DataFrame(array, columns=['followers_count','media_count','profile_picture_url','username','name','biography','id'])
df.to_excel('data.xlsx')

# %% [markdown]
# # PRUEBAS

# %%
from classes.nombre import Get_user
from classes.fecha import Get_posts

# %%
menu = str(input("Que desea hacer? \n" + 
    "1. Get Usuario\n" + 
    "2. Get Post \n" + 
    "3. Salir\n" +
    ">> "
    ))

if(menu == "1"):
        user = str(input("Ingrese username de la cuenta que desea buscar: "))
        req = Get_user(user)
        req.getAccountInfo()
        req.displayData()

elif(menu == "2"):

        user = str(input("Ingrese username de la cuenta que desea buscar: "))
        fecha_ini = str(input("Año inicial en formato (aaaa-m-d)\n")) #2019-01-01
        fecha_fin = str(input("Año final en formato (aaaa-m-d)\n")) #2020-12-31

        req = Get_posts( user, fecha_ini, fecha_fin )
        req.getAccountPosts()
        req.displayData()
            
elif(menu == "3"):
    print('adios')
else:
    print("\n Dato no valido!!!!")
    print("\n")
pass
# Out:
# C:\Python38\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'graph.facebook.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Python38\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'graph.facebook.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                    followers_count  follows_count  media_count  \
# id
# 17841401086937190              532            764           30
#
#                                                  profile_picture_url  \
# id
# 17841401086937190  https://scontent-bog1-1.xx.fbcdn.net/v/t51.288...
#
#                         username                name  \
# id
# ...
